# %%
from tkinter import *
from tkinter import ttk
import mysql.connector
from tkinter import messagebox
import datetime


class LibraryManagementSystem:
    def __init__(self,root):
        self.root = root
        self.root.title('Library Management System')
        self.root.geometry("1550x800+0+0")
        
        
        #variaable
        self.member_var=StringVar()
        self.prn_var=StringVar()
        self.id_var=StringVar()
        self.firstname_var=StringVar()
        self.lastname_var=StringVar()
        self.address1_var=StringVar()
        self.address2_var=StringVar()
        self.address2_var=StringVar()
        self.postcode_var=StringVar()
        self.mobile_var=StringVar()
        self.bookid_var=StringVar()
        self.booktitle_var=StringVar()
        self.author_var=StringVar()
        self.dateborrowed_var=StringVar()
        self.datedue_var=StringVar()
        self.daysonbook=StringVar()
        self.latereturnfine_var=StringVar()
        self.dateoverdue_var= StringVar()
        #self.finalprice=StringVar()
        self.actualprice=StringVar()
    
    
        
        
        lbltitle = Label(self.root,text = "LIBRARY MANAGEMENT SYSTEM", bg = "red" , fg="yellow",bd = 20, relief = RIDGE, font = ("algerian",50,"bold"),padx=2,pady=6)
        lbltitle.pack(side=TOP,fill=X)
        
        frame = Frame(self.root,bd=12,relief=RIDGE,padx=2,bg="powderblue")
        frame.place(x=0,y=130,width=1530,height = 400)
        #Dataframe Left
        DataFrameLeft=LabelFrame(frame,text="LIBRARY MEMBERSHIP INFORMATION", bg = "red" , fg="yellow",bd = 20, relief = RIDGE, font = ("calibri",12,"bold"))
        DataFrameLeft.place(x=0,y=5,width=800,height=350)
        
        lblMember=Label(DataFrameLeft,bg = "red",text="Member type",font=("times new roman",12,"bold"),padx=2,pady=6)
        lblMember.grid(row=0,column=0,sticky=W)
        
        comMember=ttk.Combobox(DataFrameLeft,font=("times new roman",15,"bold"),textvariable=self.member_var,width=27,state="readonly")
        #admin staff student lecturer changes= read only
        #comMember["value"] = ("Admin Staff","Resident","Guests")
        comMember["value"] = ("Admin Staff","Resident","Guests")
        comMember.current(0)
        comMember.grid(row=0,column=1)
        
        lblPRN_No=Label(DataFrameLeft,bg = "red",text="PRN NO.",font=("calibri",12,"bold"),padx=2,pady=6)
        lblPRN_No.grid(row=1,column=0,sticky=W)
        txtPRN_NO=Entry(DataFrameLeft,font=("calibri",12,"bold"),textvariable=self.prn_var,width=36)
        txtPRN_NO.grid(row=1,column=1)

        lblTitle=Label(DataFrameLeft,bg = "red",text="ID NO.",font=("calibri",12,"bold"),padx=2,pady=6)
        lblTitle.grid(row=2,column=0,sticky=W)
        txtTitle=Entry(DataFrameLeft,font=("calibri",12,"bold"),textvariable=self.id_var,width=36)
        txtTitle.grid(row=2,column=1)
        
        lblFirstName=Label(DataFrameLeft,bg = "red",text="First Name",font=("calibri",12,"bold"),padx=2,pady=6)
        lblFirstName.grid(row=3,column=0,sticky=W)
        txtFirstName=Entry(DataFrameLeft,font=("calibri",12,"bold"),textvariable=self.firstname_var,width=36)
        txtFirstName.grid(row=3,column=1)
        
        lblLastName=Label(DataFrameLeft,bg = "red",text="Last Name",font=("calibri",12,"bold"),padx=2,pady=6)
        lblLastName.grid(row=4,column=0,sticky=W)
        txtLastName=Entry(DataFrameLeft,font=("calibri",12,"bold"),textvariable=self.lastname_var,width=36)
        txtLastName.grid(row=4,column=1)
        
        lblAddress1=Label(DataFrameLeft,bg = "red",text="Address1",font=("calibri",12,"bold"),padx=2,pady=6)
        lblAddress1.grid(row=5,column=0,sticky=W)
        txtAddress1=Entry(DataFrameLeft,font=("calibri",12,"bold"),textvariable=self.address1_var,width=36)
        txtAddress1.grid(row=5,column=1)
        
        lblAddress2=Label(DataFrameLeft,bg = "red",text="Address2",font=("calibri",12,"bold"),padx=2,pady=6)
        lblAddress2.grid(row=6,column=0,sticky=W)
        txtAddress2=Entry(DataFrameLeft,font=("calibri",12,"bold"),textvariable=self.address2_var,width=36)
        txtAddress2.grid(row=6,column=1)
        
        lblPostCode=Label(DataFrameLeft,bg = "red",text="Post Code",font=("calibri",12,"bold"),padx=2,pady=6)
        lblPostCode.grid(row=7,column=0,sticky=W)
        txtPostCode=Entry(DataFrameLeft,font=("calibri",12,"bold"),textvariable=self.postcode_var,width=36)
        txtPostCode.grid(row=7,column=1)
        
        lblMobile=Label(DataFrameLeft,bg = "red",text="Mobile",font=("calibri",12,"bold"),padx=2,pady=6)
        lblMobile.grid(row=8,column=0,sticky=W)
        txtMobile=Entry(DataFrameLeft,font=("calibri",12,"bold"),textvariable=self.mobile_var,width=36)
        txtMobile.grid(row=8,column=1)
        
        lblBookId=Label(DataFrameLeft,bg = "red",text="Book Id.",font=("calibri",12,"bold"),padx=2,pady=6)
        lblBookId.grid(row=0,column=2,sticky=W)
        txtBookId=Entry(DataFrameLeft,font=("calibri",12,"bold"),textvariable=self.bookid_var,width=29)
        txtBookId.grid(row=0,column=3)
        
        lblBookTitle=Label(DataFrameLeft,bg = "red",text="Book Title",font=("calibri",12,"bold"),padx=2,pady=6)
        lblBookTitle.grid(row=1,column=2,sticky=W)
        txtBookTitle=Entry(DataFrameLeft,font=("calibri",12,"bold"),textvariable=self.booktitle_var,width=29)
        txtBookTitle.grid(row=1,column=3)
        
        lblAuthorName=Label(DataFrameLeft,bg = "red",text="Author Name",font=("calibri",12,"bold"),padx=2,pady=6)
        lblAuthorName.grid(row=2,column=2,sticky=W)
        txtAuthorName=Entry(DataFrameLeft,font=("calibri",12,"bold"),textvariable=self.author_var,width=29)
        txtAuthorName.grid(row=2,column=3)
        
        lblDateBorrowed=Label(DataFrameLeft,bg = "red",text="Date Borrowed",font=("calibri",12,"bold"),padx=2,pady=6)
        lblDateBorrowed.grid(row=3,column=2,sticky=W)
        txtDateBorrowed=Entry(DataFrameLeft,font=("calibri",12,"bold"),textvariable=self.dateborrowed_var,width=29)
        txtDateBorrowed.grid(row=3,column=3)
        
        lblDateDue=Label(DataFrameLeft,bg = "red",text="Date Due",font=("calibri",12,"bold"),padx=2,pady=6)
        lblDateDue.grid(row=4,column=2,sticky=W)
        txtDateDue=Entry(DataFrameLeft,font=("calibri",12,"bold"),textvariable=self.datedue_var,width=29)
        txtDateDue.grid(row=4,column=3)
        
        lblDaysonBook=Label(DataFrameLeft,bg = "red",text="Days on Book",font=("calibri",12,"bold"),padx=2,pady=6)
        lblDaysonBook.grid(row=5,column=2,sticky=W)
        txtDaysonBook=Entry(DataFrameLeft,font=("calibri",12,"bold"),textvariable=self.daysonbook,width=29)
        txtDaysonBook.grid(row=5,column=3)
        
        lblLateReturnFine=Label(DataFrameLeft,bg = "red",text="Late Return Fine:",font=("calibri",12,"bold"),padx=2,pady=6)
        lblLateReturnFine.grid(row=6,column=2,sticky=W)
        txtLateReturnFine=Entry(DataFrameLeft,font=("calibri",12,"bold"),textvariable=self.latereturnfine_var,width=29)
        txtLateReturnFine.grid(row=6,column=3)
        
        lblDateOverDue=Label(DataFrameLeft,bg = "red",text="Date Over Due:",font=("calibri",12,"bold"),padx=2,pady=6)
        lblDateOverDue.grid(row=7,column=2,sticky=W)
        txtDateOverDue=Entry(DataFrameLeft,font=("calibri",12,"bold"),textvariable=self.dateoverdue_var,width=29)
        txtDateOverDue.grid(row=7,column=3)
        
        lblActualPrice=Label(DataFrameLeft,bg = "red",text="Actual Price:",font=("calibri",12,"bold"),padx=2,pady=6)
        lblActualPrice.grid(row=8,column=2,sticky=W)
        txtActualPrice=Entry(DataFrameLeft,font=("calibri",12,"bold"),textvariable=self.actualprice,width=29)
        txtActualPrice.grid(row=8,column=3)
        
#         l = ["ds","PRN NO.",
# "ID NO.",
# "First Name.",
# "Last Name.",
# "Address1",
# "Address2",
# "Post Code",
# "Mobile",
# "Book Id.",
# "Book Title",
# "Author Name",
# "Date Borrowed",
# "Date Due",
# "Days on Book",
# "Late Return Fine:",
# "Date Over Due:",
# "Actual Price:"]
#         print(len(l))
#         for i in range(1,len(l)+1):
#             if i <=8 and i != len(l)+1 :
#                 lblActualPrice=Label(DataFrameLeft,bg = "red",text=f"{l[i]}",font=("calibri",12,"bold"),padx=2,pady=6)
#                 lblActualPrice.grid(row=i,column=0,sticky=W)
#                 txtActualPrice=Entry(DataFrameLeft,font=("calibri",12,"bold"),width=36)
#                 txtActualPrice.grid(row=i,column=1)
# #                 len
# #                 print(l[i])
#                 j=i
#             elif i<=len(l)-1:
#                 lblActualPrice=Label(DataFrameLeft,bg = "red",text=f"{l[i]}",font=("calibri",12,"bold"),padx=2,pady=6)
#                 lblActualPrice.grid(row=i-j-1,column=2,sticky=W)
#                 txtActualPrice=Entry(DataFrameLeft,font=("calibri",12,"bold"),width=29)
#                 txtActualPrice.grid(row=i-j-1,column=3)
#                 #print(l[i])
#                 #print(i-j-1)
#                 n = 2
#                 m = 3
        
        
        
        #txnPRN_No = Entry(DataFrameLeft,font=' ')
        #============================DataframeRIght
        DataFrameRight=LabelFrame(frame,bd =12,padx=10,text="Book Details", bg = "red" , fg="yellow", relief = RIDGE, font = ("calibri",12,"bold"))
        DataFrameRight.place(x=800,y=5,width=580,height=350)
        
        self.txtBox=Text(DataFrameRight,font=("arial",12,"bold"),width=32,height=16,padx=2,pady=6)
        self.txtBox.grid(row=0,column=2)
        
        listScrollbar=Scrollbar(DataFrameRight)
        listScrollbar.grid(row=0,column=0,sticky="ns")
        
        listBooks=["Way of kings","Odessey","Elantris","The Alloy of Law","Shadows of self","The Emperor's Soul"]
        
        def SelectBook(event=""):
            value=str(listBox.get(listBox.curselection))
            x = value
            if (x=="Head first Book"):
                self.bookid_var.set("BKID1234")
                self.booktitle_var.set("Way of Kings")
                self.author_var.set("Brandon Sanderson")
                
                d1 = datetime.datetime.today()
                #taken 30 not 15 here
                d2 = datetime.timedelta(days=30)
                d3 = d1+d2
                self.dateborrowed_var.set(d1)
                self.datedue_var.set(d3)
                self.daysonbook.set(30)
                self.latereturnfine_var.set(100)
                self.dateoverdue_var.set("No")
                self.actualprice.set("Rs. 350")
        
            
        
        listBox=Listbox(DataFrameRight,font=("calibri",12,"bold"),width=20,height=16)
        listBox.bind("<<ListBoxSelect>>",SelectBook)
        listBox.grid(row=0,column=0,padx=4)
        listScrollbar.config(command=listBox.yview)
        
        for item in listBooks:
            listBox.insert(END,item)
        #buttons
        framebutton=Frame(self.root,bd=12,relief=RIDGE,padx=2,bg="powderblue")
        framebutton.place(x=0,y=530,width=1530,height = 70)
        
        ls = ["Add Data","Show Data","Update","Delete","Reset","Exit"]
        for i in range(len(ls)):
            
            btnAddData=Button(framebutton,command=self.add_data,text=f"{ls[i]}",font=("arial",12,"bold"),width=22,bg="red",fg="yellow")
            btnAddData.grid(row=0,column=i)
        
        
        
        # Information
        FrameDetails=Frame(self.root,bd=12,relief=RIDGE,padx=2,bg="powderblue")
        FrameDetails.place(x=0,y=600,width=1530,height = 400)
        
        Table_Frame=Frame(FrameDetails,bd=6,relief=RIDGE,bg="red")
        Table_Frame.place(x=0,y=2,width=1400,height=190)
        
        xscroll=ttk.Scrollbar(Table_Frame,orient=HORIZONTAL)
        yscroll=ttk.Scrollbar(Table_Frame,orient=VERTICAL)
        
        self.library_table=ttk.Treeview(Table_Frame,column=("Member Type","PRN NO.",
"ID NO.",
"First Name",
"Last Name",
"Address1",
"Address2",
"Post Code",
"Mobile",
"Book Id.",
"Book Title",
"Author Name",
"Date Borrowed",
"Date Due",
"Days on Book",
"Late Return Fine:",
"Date Over Due:",
"Actual Price:"),xscrollcommand=xscroll.set,yscrollcommand=yscroll.set)
        
        xscroll.pack(side=BOTTOM,fill=X)
        yscroll.pack(side=RIGHT,fill=Y)
        
        xscroll.config(command=self.library_table.yview)
        yscroll.config(command=self.library_table.xview)
        lf = ["Member Type","PRN NO.",
"ID NO.",
"First Name",
"Last Name",
"Address1",
"Address2",
"Post Code",
"Mobile",
"Book Id.",
"Book Title",
"Author Name",
"Date Borrowed",
"Date Due",
"Days on Book",
"Late Return Fine:",
"Date Over Due:",
"Actual Price:"]

        
        for i in range(len(lf)):
            self.library_table.heading(f"{lf[i]}",text =f"{lf[i]}")
            self.library_table.column(f"{lf[i]}",width=100)
        self.library_table["show"]="headings"
        self.library_table.pack(fill=BOTH,expand=1)
        
    def add_data(self):
        conn=mysql.connector.connect(host="localhost",username="root",passwd="191141@Sapy",database="mydata")
        my_cursor=conn.cursor()
        
#         not working says i missed a comma or some
        my_cursor.execute("insert into library values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)",(
        self.member_var.get(),
        self.prn_var.get(),
        self.id_var.get(),
        self.firstname_var.get(),
        self.lastname_var.get(),
        self.address1_var.get(),
        self.address2_var.get(),
        self.postcode_var.get(),
        self.mobile_var.get(),
        self.bookid_var.get(),
        self.booktitle_var.get(),
        self.author_var.get(),
        self.dateborrowed_var.get(),
        self.datedue_var.get(),
        self.daysonbook.get(),
        self.latereturnfine_var.get(),
        self.dateoverdue_var.get(),
        self.actualprice.get()
        ))
        
        conn.commit()
        conn.close()
                          
        messagebox.showinfo("Success","Member has been inserted successfully")
        
if __name__ == "__main__":
    root = Tk()
    obj=LibraryManagementSystem(root)
    root.mainloop()
