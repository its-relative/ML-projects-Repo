# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("train.csv")
dataset
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df = dataset.copy()

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.isna().sum()[df.isna().any()]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
(df["MasVnrType"].mode())[0]
# Out:
# 'BrkFace'

# %%
# segregating depending upon mean mode median or just None to fill values
for i in ["MasVnrType","Electrical"]:
    df[i].fillna(value=df[i].mode()[0], inplace = True)

# %%
df.isna().sum()[df.isna().any()]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
# filling with mean(for continuous variables)

for j in ["LotFrontage", "MasVnrArea"]:
    df[j].fillna(value=df[j].mean(), inplace=True)

# %%
df.isna().sum()[df.isna().any()]
# Out:
# Alley           1369
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
# Filling with None for none valued Nans

for k in ["BsmtQual",
"BsmtCond",
"BsmtExposure",
"BsmtFinType1",
"BsmtFinType2",
"FireplaceQu",
"GarageType",
"GarageYrBlt",
"GarageFinish",
"GarageQual",
"GarageCond"]:
    df[k].fillna(value="None", inplace= True)

# %%
df.isna().sum()[df.isna().any()]
# Out:
# Alley          1369
# PoolQC         1453
# Fence          1179
# MiscFeature    1406
# dtype: int64

# %%
pd.set_option("display.max_rows",100)

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df2 = df.copy()

# %%
df2.isna().sum()[df2.isna().any()]
# Out:
# Alley          1369
# PoolQC         1453
# Fence          1179
# MiscFeature    1406
# dtype: int64

# %%
# from scipy.stats import f_oneway

# %%
# def anova_correlation_calculator(st,y):
#     cat_names = []
#     for i in range(len(df[st].value_counts())):
#         cat_names.append(df[st].value_counts().keys()[i])


#     sec_list = [list(df[df[st] == i ][y]) for i in cat_names]
#     final = f_oneway(*sec_list)
#     if final[1] > 0.05:
#         return "Correlated"
#     else:
#         return "Not Correlated"

# %%
# anova_correlation_calculator("Alley","SalePrice")

# %%
# anova_correlation_calculator("MiscFeature","SalePrice")
# df2["PoolQC"].value_counts()

# %%
drop_dead = list(df.isna().sum()[df.isna().any()].keys())

# %%
drop_dead
# Out:
# ['Alley', 'PoolQC', 'Fence', 'MiscFeature']

# %%
for i in drop_dead:
    df2.drop(columns=i,inplace= True)

# %%
df2.isna().sum()[df2.isna().any()]
# Out:
# Series([], dtype: int64)

# %%
# df2.dtypes.items()
dtypeDict = {k: v for k,v in df2.dtypes.items()}

# %%
objList = []
# type(dtypeDict["Id"])
for i in df2.columns:
    if df2[i].dtype == "object":
        objList.append(i)

# %%
objList
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
intList = []
for i in df2.columns:
    if df2[i].dtype == "int64" and "float64":
        intList.append(i)

# %%
intList
# Out:
# ['Id',
#  'MSSubClass',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
dfLinear = df[intList]

# %%
# dtypeDict

# # intList = [k for k,v in dtypeDict.items() if v == "dtype('int64')" and v == "dtype('float64')"]

# intList = []
# for k,v in dtypeDict:
    # print(k,v)
    # if v == "dtype('int64')":
        # intList.append(k)

# %%
intList
# Out:
# ['Id',
#  'MSSubClass',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
x = dfLinear.iloc[:,:-1].values
y = dfLinear.iloc[:,-1:].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.33, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
import matplotlib.pyplot as plt

# %%
x_train
# Out:
# array([[ 616,   85, 8800, ...,    0,    5, 2010],
#        [ 614,   20, 8402, ...,    0,   12, 2007],
#        [1304,   20, 8688, ...,    0,    4, 2006],
#        ...,
#        [1295,   20, 8172, ...,    0,    4, 2006],
#        [ 861,   50, 7642, ...,    0,    6, 2007],
#        [1127,  120, 3684, ...,    0,    6, 2009]])

# %%
len(y_train)
# Out:
# 978

# %%
plt.scatter(y_pred,y_test)
plt.xlabel("X")
plt.ylabel("y")
plt.show()
