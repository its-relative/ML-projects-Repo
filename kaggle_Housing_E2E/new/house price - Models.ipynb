# %%
import pandas  as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler,MinMaxScaler,LabelEncoder,OneHotEncoder
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %%
hp_df = pd.read_csv('house_price_data.csv') # dataframe(equivalent to table)

y = hp_df['SalePrice']

hp_df.drop(columns = ["SalePrice",'Id'],inplace = True)

# %%
cat_cols = [col for col in hp_df.columns if hp_df[col].dtype == 'object']
con_cols = [col for col in hp_df.columns if hp_df[col].dtype != 'object']

# %%
X_train,X_test,y_train,y_test = train_test_split(hp_df,y,random_state = 42, test_size = 0.2)

# %%
"""
Fill the NAs
Scaling the continuous features
Encoding the categorical features

"""
# Out:
# '\nFill the NAs\nScaling the continuous features\nEncoding the categorical features\n\n'

# %%
for col in X_train.columns:
    if hp_df[col].dtype == 'object':
        X_train[col].fillna(X_train[col].mode()[0],inplace = True)
        X_test[col].fillna(X_train[col].mode()[0],inplace = True) #filling with train mode
        
    if hp_df[col].dtype != 'object':
        X_train[col].fillna(X_train[col].mean(),inplace = True)
        X_test[col].fillna(X_train[col].mean(),inplace = True) #filling with train mode

# %%
# Standard Scaler

scaler = StandardScaler()
min_max_scaler = MinMaxScaler()

for col in con_cols:
    X_train[col] = min_max_scaler.fit_transform(np.array(X_train[col]).reshape(-1,1))
    X_test[col] = min_max_scaler.transform(np.array(X_test[col]).reshape(-1,1))

# %%
X_train[con_cols].index
# Out:
# Int64Index([ 254, 1066,  638,  799,  380,  303,   86, 1385,  265,  793,
#             ...
#              330, 1238,  466,  121, 1044, 1095, 1130, 1294,  860, 1126],
#            dtype='int64', length=1168)

# %%
# One-Hot Encoding

oe = OneHotEncoder(handle_unknown='ignore')

oe_train = pd.DataFrame(oe.fit_transform(X_train[cat_cols]).toarray(),index = X_train[con_cols].index)
oe_test = pd.DataFrame(oe.transform(X_test[cat_cols]).toarray(),index = X_test[con_cols].index)

# %%
train_final = pd.concat([X_train[con_cols],oe_train],axis = 1)
test_final = pd.concat([X_test[con_cols],oe_test],axis = 1)

# %%
linreg = LinearRegression()

linreg.fit(train_final,y_train)
# Out:
# LinearRegression()

# %%
coefficients = linreg.coef_

# %%
y_pred = linreg.predict(test_final)

# %%
r2_score(y_test,y_pred)
# Out:
# -1.5075566284102294e+19

# %%
dtree = DecisionTreeRegressor(random_state=42)

dtree.fit(train_final,y_train)

dtree_pred = dtree.predict(test_final)

# %%
r2_score(y_test,dtree_pred)
# Out:
# 0.7751652658329957

# %%
rf_regressor = RandomForestRegressor()

# %%
# GridSearchCV
# RandomisedSearchCV
rf_param_dict = {
                'n_estimators': [40,60,70,80],
                'max_depth' : [10,12,14],
                'min_samples_split': [5,6,7,8],
                'max_leaf_nodes': [6,7,8,9]
                }

gcv = GridSearchCV(rf_regressor,param_grid=rf_param_dict,cv = 5,verbose =32)

gcv.fit(train_final,y_train)
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# [CV 1/5; 1/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=5, n_estimators=40
# [CV 1/5; 1/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=5, n_estimators=40; total time=   0.3s
# [CV 2/5; 1/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=5, n_estimators=40
# [CV 2/5; 1/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=5, n_estimators=40; total time=   0.2s
# [CV 3/5; 1/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=5, n_estimators=
192] END max_depth=10, max_leaf_nodes=6, min_samples_split=7, n_estimators=70; total time=   0.8s
# [CV 3/5; 11/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=7, n_estimators=70
# [CV 3/5; 11/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=7, n_estimators=70; total time=   0.7s
# [CV 4/5; 11/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=7, n_estimators=70
# [CV 4/5; 11/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=7, n_estimators=70; total time=   0.6s
# [CV 5/5; 11/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=7, n_estimators=70
# [CV 5/5; 11/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=7, n_estimators=70; total time=   0.6s
# [CV 1/5; 12/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=7, n_estimators=80
# [CV 1/5; 12/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=7, n_estimators=80; total time=   0.8s
# [CV 2/5; 12/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=7, n_estimators=80
# [CV 2/5; 12/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=7, n_estimators=80; total time=   0.8s
# [CV 3/5; 12/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=7, n_estimators=80
# [CV 3/5; 12/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=7, n_estimators=80; total time=   0.8s
# [CV 4/5; 12/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=7, n_estimators=80
# [CV 4/5; 12/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=7, n_estimators=80; total time=   0.8s
# [CV 5/5; 12/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=7, n_estimators=80
# [CV 5/5; 12/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=7, n_estimators=80; total time=   0.7s
# [CV 1/5; 13/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=40
# [CV 1/5; 13/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=40; total time=   0.4s
# [CV 2/5; 13/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=40
# [CV 2/5; 13/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=40; total time=   0.4s
# [CV 3/5; 13/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=40
# [CV 3/5; 13/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=40; total time=   0.5s
# [CV 4/5; 13/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=40
# [CV 4/5; 13/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=40; total time=   0.4s
# [CV 5/5; 13/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=40
# [CV 5/5; 13/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=40; total time=   0.4s
# [CV 1/5; 14/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=60
# [CV 1/5; 14/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=60; total time=   0.7s
# [CV 2/5; 14/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=60
# [CV 2/5; 14/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=60; total time=   0.7s
# [CV 3/5; 14/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=60
# [CV 3/5; 14/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=60; total time=   0.6s
# [CV 4/5; 14/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=60
# [CV 4/5; 14/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=60; total time=   0.6s
# [CV 5/5; 14/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=60
# [CV 5/5; 14/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=60; total time=   0.6s
# [CV 1/5; 15/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=70
# [CV 1/5; 15/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=70; total time=   0.6s
# [CV 2/5; 15/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=70
# [CV 2/5; 15/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=70; total time=   0.6s
# [CV 3/5; 15/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=70
# [CV 3/5; 15/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=70; total time=   0.6s
# [CV 4/5; 15/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=70
# [CV 4/5; 15/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=70; total time=   0.6s
# [CV 5/5; 15/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=70
# [CV 5/5; 15/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=70; total time=   0.7s
# [CV 1/5; 16/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=80
# [CV 1/5; 16/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=80; total time=   0.8s
# [CV 2/5; 16/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=80
# [CV 2/5; 16/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=80; total time=   0.9s
# [CV 3/5; 16/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=80
# [CV 3/5; 16/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=80; total time=   0.9s
# [CV 4/5; 16/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=80
# [CV 4/5; 16/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=80; total time=   0.8s
# [CV 5/5; 16/192] START max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=80
# [CV 5/5; 16/192] END max_depth=10, max_leaf_nodes=6, min_samples_split=8, n_estimators=80; total time=   0.8s
# [CV 1/5; 17/192] START max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=40
# [CV 1/5; 17/192] END max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=40; total time=   0.5s
# [CV 2/5; 17/192] START max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=40
# [CV 2/5; 17/192] END max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=40; total time=   0.4s
# [CV 3/5; 17/192] START max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=40
# [CV 3/5; 17/192] END max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=40; total time=   0.5s
# [CV 4/5; 17/192] START max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=40
# [CV 4/5; 17/192] END max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=40; total time=   0.5s
# [CV 5/5; 17/192] START max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=40
# [CV 5/5; 17/192] END max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=40; total time=   0.6s
# [CV 1/5; 18/192] START max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=60
# [CV 1/5; 18/192] END max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=60; total time=   0.7s
# [CV 2/5; 18/192] START max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=60
# [CV 2/5; 18/192] END max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=60; total time=   0.7s
# [CV 3/5; 18/192] START max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=60
# [CV 3/5; 18/192] END max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=60; total time=   0.8s
# [CV 4/5; 18/192] START max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=60
# [CV 4/5; 18/192] END max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=60; total time=   0.8s
# [CV 5/5; 18/192] START max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=60
# [CV 5/5; 18/192] END max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=60; total time=   0.7s
# [CV 1/5; 19/192] START max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=70
# [CV 1/5; 19/192] END max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=70; total time=   0.8s
# [CV 2/5; 19/192] START max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=70
# [CV 2/5; 19/192] END max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=70; total time=   0.8s
# [CV 3/5; 19/192] START max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=70
# [CV 3/5; 19/192] END max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=70; total time=   0.7s
# [CV 4/5; 19/192] START max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=70
# [CV 4/5; 19/192] END max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=70; total time=   0.8s
# [CV 5/5; 19/192] START max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=70
# [CV 5/5; 19/192] END max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=70; total time=   0.8s
# [CV 1/5; 20/192] START max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=80
# [CV 1/5; 20/192] END max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=80; total time=   0.9s
# [CV 2/5; 20/192] START max_depth=10, max_leaf_nodes=7, min_samples_split=5, n_estimators=
192] START max_depth=10, max_leaf_nodes=8, min_samples_split=8, n_estimators=70
# [CV 2/5; 47/192] END max_depth=10, max_leaf_nodes=8, min_samples_split=8, n_estimators=70; total time=   1.2s
# [CV 3/5; 47/192] START max_depth=10, max_leaf_nodes=8, min_samples_split=8, n_estimators=70
# [CV 3/5; 47/192] END max_depth=10, max_leaf_nodes=8, min_samples_split=8, n_estimators=70; total time=   1.1s
# [CV 4/5; 47/192] START max_depth=10, max_leaf_nodes=8, min_samples_split=8, n_estimators=70
# [CV 4/5; 47/192] END max_depth=10, max_leaf_nodes=8, min_samples_split=8, n_estimators=70; total time=   0.9s
# [CV 5/5; 47/192] START max_depth=10, max_leaf_nodes=8, min_samples_split=8, n_estimators=70
# [CV 5/5; 47/192] END max_depth=10, max_leaf_nodes=8, min_samples_split=8, n_estimators=70; total time=   0.8s
# [CV 1/5; 48/192] START max_depth=10, max_leaf_nodes=8, min_samples_split=8, n_estimators=80
# [CV 1/5; 48/192] END max_depth=10, max_leaf_nodes=8, min_samples_split=8, n_estimators=80; total time=   0.9s
# [CV 2/5; 48/192] START max_depth=10, max_leaf_nodes=8, min_samples_split=8, n_estimators=80
# [CV 2/5; 48/192] END max_depth=10, max_leaf_nodes=8, min_samples_split=8, n_estimators=80; total time=   0.9s
# [CV 3/5; 48/192] START max_depth=10, max_leaf_nodes=8, min_samples_split=8, n_estimators=80
# ...
# [CV 4/5; 177/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=40; total time=   0.4s
# [CV 5/5; 177/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=40
# [CV 5/5; 177/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=40; total time=   0.3s
# [CV 1/5; 178/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=60
# [CV 1/5; 178/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=60; total time=   0.5s
# [CV 2/5; 178/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=60
# [CV 2/5; 178/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=60; total time=   0.5s
# [CV 3/5; 178/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=60
# [CV 3/5; 178/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=60; total time=   0.5s
# [CV 4/5; 178/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=60
# [CV 4/5; 178/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=60; total time=   0.5s
# [CV 5/5; 178/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=60
# [CV 5/5; 178/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=60; total time=   0.5s
# [CV 1/5; 179/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=70
# [CV 1/5; 179/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=70; total time=   0.6s
# [CV 2/5; 179/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=70
# [CV 2/5; 179/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=70; total time=   0.6s
# [CV 3/5; 179/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=70
# [CV 3/5; 179/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=70; total time=   0.6s
# [CV 4/5; 179/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=70
# [CV 4/5; 179/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=70; total time=   0.6s
# [CV 5/5; 179/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=70
# [CV 5/5; 179/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=70; total time=   0.6s
# [CV 1/5; 180/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=80
# [CV 1/5; 180/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=80; total time=   0.7s
# [CV 2/5; 180/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=80
# [CV 2/5; 180/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=80; total time=   0.7s
# [CV 3/5; 180/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=80
# [CV 3/5; 180/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=80; total time=   0.7s
# [CV 4/5; 180/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=80
# [CV 4/5; 180/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=80; total time=   0.7s
# [CV 5/5; 180/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=80
# [CV 5/5; 180/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=5, n_estimators=80; total time=   0.7s
# [CV 1/5; 181/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=40
# [CV 1/5; 181/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=40; total time=   0.4s
# [CV 2/5; 181/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=40
# [CV 2/5; 181/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=40; total time=   0.4s
# [CV 3/5; 181/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=40
# [CV 3/5; 181/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=40; total time=   0.4s
# [CV 4/5; 181/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=40
# [CV 4/5; 181/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=40; total time=   0.4s
# [CV 5/5; 181/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=40
# [CV 5/5; 181/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=40; total time=   0.3s
# [CV 1/5; 182/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=60
# [CV 1/5; 182/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=60; total time=   0.5s
# [CV 2/5; 182/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=60
# [CV 2/5; 182/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=60; total time=   0.5s
# [CV 3/5; 182/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=60
# [CV 3/5; 182/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=60; total time=   0.5s
# [CV 4/5; 182/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=60
# [CV 4/5; 182/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=60; total time=   0.5s
# [CV 5/5; 182/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=60
# [CV 5/5; 182/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=60; total time=   0.5s
# [CV 1/5; 183/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=70
# [CV 1/5; 183/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=70; total time=   0.6s
# [CV 2/5; 183/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=70
# [CV 2/5; 183/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=70; total time=   0.7s
# [CV 3/5; 183/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=70
# [CV 3/5; 183/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=70; total time=   0.6s
# [CV 4/5; 183/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=70
# [CV 4/5; 183/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=70; total time=   0.6s
# [CV 5/5; 183/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=70
# [CV 5/5; 183/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=70; total time=   0.6s
# [CV 1/5; 184/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=80
# [CV 1/5; 184/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=80; total time=   0.7s
# [CV 2/5; 184/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=80
# [CV 2/5; 184/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=80; total time=   0.7s
# [CV 3/5; 184/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=80
# [CV 3/5; 184/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=80; total time=   0.7s
# [CV 4/5; 184/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=80
# [CV 4/5; 184/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=80; total time=   0.7s
# [CV 5/5; 184/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=80
# [CV 5/5; 184/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=6, n_estimators=80; total time=   0.7s
# [CV 1/5; 185/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=40
# [CV 1/5; 185/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=40; total time=   0.4s
# [CV 2/5; 185/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=40
# [CV 2/5; 185/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=40; total time=   0.4s
# [CV 3/5; 185/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=40
# [CV 3/5; 185/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=40; total time=   0.5s
# [CV 4/5; 185/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=40
# [CV 4/5; 185/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=40; total time=   0.4s
# [CV 5/5; 185/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=40
# [CV 5/5; 185/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=40; total time=   0.4s
# [CV 1/5; 186/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=60
# [CV 1/5; 186/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=60; total time=   0.7s
# [CV 2/5; 186/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=60
# [CV 2/5; 186/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=60; total time=   0.6s
# [CV 3/5; 186/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=60
# [CV 3/5; 186/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=60; total time=   0.6s
# [CV 4/5; 186/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=60
# [CV 4/5; 186/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=60; total time=   0.6s
# [CV 5/5; 186/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=60
# [CV 5/5; 186/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=60; total time=   0.6s
# [CV 1/5; 187/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=70
# [CV 1/5; 187/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=70; total time=   0.6s
# [CV 2/5; 187/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=70
# [CV 2/5; 187/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=70; total time=   0.6s
# [CV 3/5; 187/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=70
# [CV 3/5; 187/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=70; total time=   0.6s
# [CV 4/5; 187/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=70
# [CV 4/5; 187/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=70; total time=   0.7s
# [CV 5/5; 187/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=70
# [CV 5/5; 187/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=70; total time=   0.6s
# [CV 1/5; 188/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=80
# [CV 1/5; 188/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=80; total time=   0.7s
# [CV 2/5; 188/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=80
# [CV 2/5; 188/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=80; total time=   0.7s
# [CV 3/5; 188/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=80
# [CV 3/5; 188/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=80; total time=   0.7s
# [CV 4/5; 188/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=80
# [CV 4/5; 188/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=80; total time=   0.7s
# [CV 5/5; 188/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=80
# [CV 5/5; 188/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=7, n_estimators=80; total time=   0.7s
# [CV 1/5; 189/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=40
# [CV 1/5; 189/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=40; total time=   0.4s
# [CV 2/5; 189/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=40
# [CV 2/5; 189/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=40; total time=   0.4s
# [CV 3/5; 189/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=40
# [CV 3/5; 189/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=40; total time=   0.3s
# [CV 4/5; 189/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=40
# [CV 4/5; 189/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=40; total time=   0.4s
# [CV 5/5; 189/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=40
# [CV 5/5; 189/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=40; total time=   0.4s
# [CV 1/5; 190/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=60
# [CV 1/5; 190/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=60; total time=   0.5s
# [CV 2/5; 190/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=60
# [CV 2/5; 190/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=60; total time=   0.5s
# [CV 3/5; 190/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=60
# [CV 3/5; 190/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=60; total time=   0.5s
# [CV 4/5; 190/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=60
# [CV 4/5; 190/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=60; total time=   0.6s
# [CV 5/5; 190/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=60
# [CV 5/5; 190/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=60; total time=   0.5s
# [CV 1/5; 191/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=70
# [CV 1/5; 191/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=70; total time=   0.6s
# [CV 2/5; 191/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=70
# [CV 2/5; 191/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=70; total time=   0.6s
# [CV 3/5; 191/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=70
# [CV 3/5; 191/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=70; total time=   0.7s
# [CV 4/5; 191/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=70
# [CV 4/5; 191/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=70; total time=   0.6s
# [CV 5/5; 191/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=70
# [CV 5/5; 191/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=70; total time=   0.6s
# [CV 1/5; 192/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=80
# [CV 1/5; 192/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=80; total time=   0.7s
# [CV 2/5; 192/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=80
# [CV 2/5; 192/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=80; total time=   0.7s
# [CV 3/5; 192/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=80
# [CV 3/5; 192/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=80; total time=   0.9s
# [CV 4/5; 192/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=80
# [CV 4/5; 192/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=80; total time=   0.7s
# [CV 5/5; 192/192] START max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=80
# [CV 5/5; 192/192] END max_depth=14, max_leaf_nodes=9, min_samples_split=8, n_estimators=80; total time=   0.7s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [10, 12, 14],
#                          'max_leaf_nodes': [6, 7, 8, 9],
#                          'min_samples_split': [5, 6, 7, 8],
#                          'n_estimators': [40, 60, 70, 80]},
#              verbose=32)

# %%
gcv.best_params_

gcv.best_score_
# Out:
# 0.7563957103772969

# %%
# GridSearchCV
# RandomisedSearchCV
rf_param_dict = {
                'n_estimators': [40,60,70,80],
                'max_depth' : [10,12,14],
                'min_samples_split': [5,6,7,8],
                'max_leaf_nodes': [6,7,8,9]
                }

rcv = RandomizedSearchCV(rf_regressor,param_grid=rf_param_dict,cv = 5,verbose =32,n_iter = 100)

rcv.fit(train_final,y_train)
